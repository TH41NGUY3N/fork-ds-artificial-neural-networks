# %% [markdown]
# # Basic regression: Predict fuel efficiency

# %% [markdown]
# *This notebook is based on the [tutorial notebook](https://www.tensorflow.org/tutorials/keras/regression) provided by TensorFlow.*
#
# ---
# In a *regression* problem, we aim to predict the output of a continuous value, like a price or a probability.
#
# This notebook uses the classic [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) Dataset, which you've already encountered in previous notebooks, and builds a model to predict the fuel efficiency of late-1970s and early 1980s automobiles. To do this, we'll provide the model with a description of many automobiles from that time period. This description includes attributes like: cylinders, displacement, horsepower, and weight.
#
# This example uses the `tf.keras` API, see [this guide](https://www.tensorflow.org/guide/keras) for details.

# %% [markdown]
# ## Setup

# %%
import time
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.layers as kl

print(tf.__version__)

from tensorflow.keras.optimizers.legacy import Adam
# Out:
# WARNING:tensorflow:From c:\Users\thngu\neuefische_course\pepperprompt\fork-ds-artificial-neural-networks\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %% [markdown]
# ### Setup for TensorBoard
#
# We will use the TensorBoard to visualize some results. You can find more information and the board itself at the end of this notebook, but we will define the path were the information should be stored directly here at the beginning.

# %%
# With this command you can clear any logs from previous runs
# If you want to compare different runs you can skip this cell
# !rm -rf my_logs/

# %%
# Define path for new directory
root_logdir = os.path.join(os.curdir, "my_logs")

# %%
# Define function for creating a new folder for each run
def get_run_logdir():
    run_id = time.strftime("run_%d_%m_%Y-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

# %%
run_logdir = get_run_logdir()

# %%
# Create function for using callbacks; "name" should be the name of the model you use
def get_callbacks(name):
    return tf.keras.callbacks.TensorBoard(run_logdir + name, histogram_freq=1)

# %% [markdown]
# ## The Auto MPG dataset
#
# The dataset is available from the [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data).

# %% [markdown]
# ### Get the data
# First download and import the dataset using pandas:

# %%
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"

column_names = [
    "MPG",
    "Cylinders",
    "Displacement",
    "Horsepower",
    "Weight",
    "Acceleration",
    "Model Year",
    "Origin",
]

raw_dataset = pd.read_csv(
    url, names=column_names, na_values="?", comment="\t", sep=" ", skipinitialspace=True
)

# %%
df = raw_dataset.copy()
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration
# 0  18.0          8         307.0       130.0  3504.0          12.0  \
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %% [markdown]
# ### Clean the data
#
# The `Horsepower` column contains a few unknown values.

# %%
df.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %% [markdown]
# Let's drop those rows to keep this tutorial simple.

# %%
df = df.dropna()

# %% [markdown]
# Let's check the datatypes and amount of unique values for each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           392 non-null    float64
#  1   Cylinders     392 non-null    int64
#  2   Displacement  392 non-null    float64
#  3   Horsepower    392 non-null    float64
#  4   Weight        392 non-null    float64
#  5   Acceleration  392 non-null    float64
#  6   Model Year    392 non-null    int64
#  7   Origin        392 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 27.6 KB

# %%
df.nunique()
# Out:
# MPG             127
# Cylinders         5
# Displacement     81
# Horsepower       93
# Weight          346
# Acceleration     95
# Model Year       13
# Origin            3
# dtype: int64

# %% [markdown]
# The `"Origin"` column is really categorical, not numeric. So we have to convert that to a one-hot/dummy:
#
# (Note: You can set up the `keras.Model` to do this kind of transformation for you. That's beyond the scope of this tutorial. See the [preprocessing layers](https://www.tensorflow.org/tutorials/structured_data/preprocessing_layers) or [Loading CSV data](https://www.tensorflow.org/tutorials/load_data/csv) tutorials for examples.)

# %%
df["Origin"] = df["Origin"].map({1: "USA", 2: "Europe", 3: "Japan"})

# %%
df = pd.get_dummies(df, prefix="", prefix_sep="", dtype="uint8")
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration
# 0  18.0          8         307.0       130.0  3504.0          12.0  \
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Europe  Japan  USA
# 0          70       0      0    1
# 1          70       0      0    1
# 2          70       0      0    1
# 3          70       0      0    1
# 4          70       0      0    1

# %% [markdown]
# ### Split the data into train and test
#
# Now we'll split the dataset into a training set and a test set.
#
# We will use the test set in the final evaluation of our models.

# %%
df_train = df.sample(frac=0.8, random_state=0)
df_test = df.drop(df_train.index)

# %% [markdown]
# ### Inspecting the data
#
# Let's have a quick look at the joint distribution of a few pairs of columns from the training set.
#
# Looking at the top row it should be clear that the fuel efficiency (MPG) is a function of all the other parameters. Looking at the other rows it should be clear that they are each functions of eachother.

# %%
sns.pairplot(df_train[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde");

# %% [markdown]
# Also look at the overall statistics, note how each feature covers a very different range:

# %%
df_train.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%
# MPG           314.0    23.310510    7.728652    10.0    17.00    22.0  \
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
#
#                   75%     max
# MPG             28.95    46.6
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# Europe           0.00     1.0
# Japan            0.00     1.0
# USA              1.00     1.0

# %% [markdown]
# ### Split features from labels
#
# Before we can start with the modelling process we need to separate our label from the dataset. This label is the value that we will train the model to predict.

# %%
X_train = df_train.copy()
X_test = df_test.copy()

y_train = X_train.pop("MPG")
y_test = X_test.pop("MPG")

# %% [markdown]
# ## Sklearn
#
# Before we start using TensorFlow and Keras, let's train a simple `LinearRegression` model from sklearn for comparison.

# %%
# Scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Initalizing and training the model
lin_reg = LinearRegression()
lin_reg.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
y_pred = lin_reg.predict(X_test_scaled)

# %%
# Evaluting model
mae = mean_absolute_error(y_test, y_pred).round(2)
mse = mean_squared_error(y_test, y_pred).round(2)

print("MAE:", mae)
print("MSE", mse)
# Out:
# MAE: 2.39
# MSE 10.17

# %% [markdown]
# We'll store the result in a dictionary in order to compare the results of different models in the end.

# %%
test_results = {}
test_results["sklearn_model"] = [mae, mse]

# %% [markdown]
# ## Normalization
#
# In the table of statistics it's easy to see how different the ranges of each feature are.

# %%
X_train.describe().transpose()[["mean", "std"]]
# Out:
#                      mean         std
# Cylinders        5.477707    1.699788
# Displacement   195.318471  104.331589
# Horsepower     104.869427   38.096214
# Weight        2990.251592  843.898596
# Acceleration    15.559236    2.789230
# Model Year      75.898089    3.675642
# Europe           0.178344    0.383413
# Japan            0.197452    0.398712
# USA              0.624204    0.485101

# %% [markdown]
# It is good practice to normalize features that use different scales and ranges.
#
# One reason this is important is because the features are multiplied by the model weights. So the scale of the outputs and the scale of the gradients are affected by the scale of the inputs.
#
# Although a model *might* converge without feature normalization, normalization makes training much more stable.

# %% [markdown]
# ### The Normalization layer
# The `preprocessing.Normalization` layer is a clean and simple way to build that preprocessing into your model.
#
# The first step is to create the layer:

# %%
normalizer = kl.Normalization()
# Out:
# WARNING:tensorflow:From c:\Users\thngu\neuefische_course\pepperprompt\fork-ds-artificial-neural-networks\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Then `.adapt()` it to the data:

# %%
X_train
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 146          4          90.0        75.0  2125.0          14.5          74  \
# 282          4         140.0        88.0  2890.0          17.3          79
# 69           8         350.0       160.0  4456.0          13.5          72
# 378          4         105.0        63.0  2125.0          14.7          82
# 331          4          97.0        67.0  2145.0          18.0          80
# ..         ...           ...         ...     ...           ...         ...
# 281          6         200.0        85.0  2990.0          18.2          79
# 229          8         400.0       180.0  4220.0          11.1          77
# 150          4         108.0        93.0  2391.0          15.5          74
# 145          4          83.0        61.0  2003.0          19.0          74
# 182          4         107.0        86.0  2464.0          15.5          76
#
#      Europe  Japan  USA
# 146       0      0    1
# 282       0      0    1
# 69        0      0    1
# 378       0      0    1
# 331       0      1    0
# ..      ...    ...  ...
# 281       0      0    1
# 229       0      0    1
# 150       0      1    0
# 145       0      1    0
# 182       1      0    0
#
# [314 rows x 9 columns]

# %%
normalizer.adapt(X_train.values)  # adapt expect an array

# %% [markdown]
# This calculates the mean and variance, and stores them in the layer.

# %%
normalizer.mean.numpy()
# Out:
# array([[   5.478,  195.318,  104.869, 2990.252,   15.559,   75.898,
#            0.178,    0.197,    0.624]], dtype=float32)

# %% [markdown]
# When the layer is called it returns the input data, with each feature independently normalized. We can have a look at the first training instance and compare the original and normalized features:

# %%
first = X_train[:1] * 1.0

with np.printoptions(precision=2, suppress=True):
    print("First example:", first)
    print()
    print("Normalized:", normalizer(first.values).numpy())
# Out:
# First example:      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 146        4.0          90.0        75.0  2125.0          14.5        74.0  \
#
#      Europe  Japan  USA
# 146     0.0    0.0  1.0
#
# Normalized: [[-0.87 -1.01 -0.79 -1.03 -0.38 -0.52 -0.47 -0.5   0.78]]

# %% [markdown]
# ## Linear regression
#
# Before building a DNN (deep neural network) model, let's start with a linear regression.

# %% [markdown]
# ### One Variable
#
# We'll start easy with a single-variable linear regression, to predict `MPG` from `Horsepower`.
#
# Training a model with `tf.keras` typically starts by defining the model architecture.
#
# In this case we'll use a `keras.Sequential` model. This model represents a sequence of steps. In this case there are two steps:
#
# 1. Normalize the input `horsepower`.
# 2. Apply a linear transformation ($y = mx+b$) to produce 1 output using `layers.Dense`.
#
# The number of _inputs_ can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# 1. First create the horsepower `Normalization` layer:

# %%
kl.Input(
    shape=[
        1,
    ]
)
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'input_1')>

# %%
horsepower = np.array(X_train["Horsepower"])  # equivalent X_train['Horsepower'].values

horsepower_normalizer = kl.Normalization(
    input_shape=[
        1,
    ],
    axis=None,
)
horsepower_normalizer.adapt(horsepower)

# %% [markdown]
# 2. Then we'll build the sequential model:

# %%
horsepower_model = tf.keras.Sequential([horsepower_normalizer, layers.Dense(units=1)])

# We can print a summary of the model architecture with the following line:
horsepower_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normaliza  (None, 1)                 3
#  tion)
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 5 (24.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# This model will predict `MPG` from `Horsepower`.
#
# Run the untrained model on the first 10 horse-power values. The output won't be good, but you'll see that it has the expected shape, `(10,1)`:

# %%
horsepower_model.predict(horsepower[:10]).shape
# Out:
# 1/1 [==============================] - 0s 99ms/step
# (10, 1)

# %%
horsepower_model.predict(horsepower[:10])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[-0.665],
#        [-0.375],
#        [ 1.227],
#        [-0.932],
#        [-0.843],
#        [-0.331],
#        [-0.998],
#        [-0.843],
#        [-0.22 ],
#        [-0.375]], dtype=float32)

# %% [markdown]
# Once the model is built, configure the training procedure using the `Model.compile()` method. The most important arguments to compile are the `loss` and the `optimizer` since these define what will be optimized (`mean_absolute_error`) and how (using the `optimizers.Adam`). We'll also define the `metrics` to use the `mean_squared_error`.

# %%
horsepower_model.compile(
    optimizer=Adam(learning_rate=0.1), loss=["mae"], metrics=["mse"]
)

# %% [markdown]
# Once the training is configured, use `Model.fit()` to execute the training:

# %%
# %%time
history = horsepower_model.fit(
    df_train["Horsepower"],
    y_train,
    epochs=100,
    # suppress logging (if you want to see the output for the different epochs set the value to 1)
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split=0.2,
    # Store information for TensorBoard
    callbacks=get_callbacks("horsepower_model"),
)
# Out:
# WARNING:tensorflow:From c:\Users\thngu\neuefische_course\pepperprompt\fork-ds-artificial-neural-networks\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\thngu\neuefische_course\pepperprompt\fork-ds-artificial-neural-networks\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# CPU times: total: 8.83 s
# Wall time: 8.79 s

# %% [markdown]
# Visualize the model's training progress using the stats stored in the `history` object.

# %%
hist = pd.DataFrame(history.history)
hist["epoch"] = history.epoch

# Show results from first 5 epochs
hist.head()
# Out:
#         loss         mse   val_loss     val_mse  epoch
# 0  22.868538  595.214661  22.938162  603.114807      0
# 1  22.067013  559.645996  22.137695  564.489868      1
# 2  21.269325  524.730835  21.338160  532.241455      2
# 3  20.461723  491.747253  20.537916  497.394958      3
# 4  19.663961  458.758270  19.737823  464.679382      4

# %%
# Show results from last 5 epochs (loss and val_loss decreased)
hist.tail()
# Out:
#         loss        mse  val_loss    val_mse  epoch
# 95  3.802836  25.559937  4.190391  25.333904     95
# 96  3.803178  25.575455  4.193875  25.372679     96
# 97  3.802320  25.538397  4.177483  25.244753     97
# 98  3.804336  25.542171  4.189800  25.322641     98
# 99  3.803849  25.554422  4.186968  25.305342     99

# %%
def plot_loss(history):
    plt.plot(history.history["loss"], label="loss")
    plt.plot(history.history["val_loss"], label="val_loss")
    plt.ylim([0, 10])
    plt.xlabel("Epoch")
    plt.ylabel("Error [MPG]")
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# We'll store the results on the test set for later:

# %%
test_results["horsepower_model"] = horsepower_model.evaluate(
    X_test["Horsepower"], y_test, verbose=0
)

# %% [markdown]
# Since this is a single variable regression it's easy to look at the model's predictions as a function of the input:

# %%
# We'll predict the MPG for 251 different values for horsepower
x = tf.linspace(0.0, 250, 251)
y = horsepower_model.predict(x)
# Out:
# 8/8 [==============================] - 0s 1ms/step

# %%
def plot_horsepower(x, y):
    plt.scatter(X_train["Horsepower"], y_train, label="Data")
    plt.plot(x, y, color="k", label="Predictions")
    plt.xlabel("Horsepower")
    plt.ylabel("MPG")
    plt.legend()

# %%
plot_horsepower(x, y)

# %% [markdown]
# ### Multiple inputs

# %% [markdown]
# You can use an almost identical setup to make predictions based on multiple inputs. This model still does the same $y = mx+b$ except that $m$ is a matrix and $b$ is a vector.
#
# This time we'll use the `Normalization` layer that was adapted to the whole dataset.

# %%
linear_model = tf.keras.Sequential([normalizer, layers.Dense(units=1)])

# %% [markdown]
# When you call this model on a batch of inputs, it produces `units=1` outputs for each example.

# %%
linear_model.predict(X_train[:10] * 1.0)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# array([[ 0.837],
#        [-0.215],
#        [-2.906],
#        [-0.092],
#        [ 2.264],
#        [-0.83 ],
#        [ 2.614],
#        [ 2.484],
#        [-0.298],
#        [ 2.985]], dtype=float32)

# %% [markdown]
# When you call the model it's weight matrices will be built. Now you can see that the `kernel` (the $m$ in $y=mx+b$) has a shape of `(9,1)`.

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_1/kernel:0' shape=(9, 1) dtype=float32, numpy=
# array([[-0.207],
#        [-0.306],
#        [-0.537],
#        [-0.51 ],
#        [ 0.418],
#        [-0.497],
#        [ 0.258],
#        [ 0.084],
#        [-0.69 ]], dtype=float32)>

# %% [markdown]
# Use the same `compile` and `fit` calls as for the single input `horsepower` model:

# %%
linear_model.compile(optimizer=Adam(learning_rate=0.1), loss=["mae"], metrics=["mse"])

# %%
# %%time
history = linear_model.fit(
    X_train * 1.0,
    y_train,
    epochs=100,
    # suppress logging (again: change it to 1 if you want to print more information about each epoch)
    verbose=1,
    # Calculate validation results on 20% of the training data
    validation_split=0.2,
    # Store information for TensorBoard
    callbacks=get_callbacks("linear_model"),
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 14ms/step - loss: 2.4941 - mse: 12.2111 - val_loss: 2.5206 - val_mse: 11.6949
# Epoch 2/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4806 - mse: 12.5982 - val_loss: 2.4518 - val_mse: 11.0293
# Epoch 3/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5055 - mse: 12.3598 - val_loss: 2.4834 - val_mse: 11.4355
# Epoch 4/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4684 - mse: 12.4147 - val_loss: 2.5016 - val_mse: 11.4456
# Epoch 5/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4772 - mse: 12.3422 - val_loss: 2.4766 - val_mse: 11.1000
# Epoch 6/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4720 - mse: 12.3821 - val_loss: 2.4627 - val_mse: 11.0272
# Epoch 7/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4940 - mse: 12.3402 - val_loss: 2.4357 - val_mse: 10.7655
# Epoch 8/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5356 - mse: 12.9515 - val_loss: 2.4897 - val_mse: 11.4770
# Epoch 9/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5083 - mse: 12.3897 - val_loss: 2.4470 - val_mse: 10.5511
# Epoch 10/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4656 - mse: 12.2845 - val_loss: 2.5262 - val_mse: 11.8689
# Epoch 11/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5065 - mse: 12.5055 - val_loss: 2.4652 - val_mse: 11.0171
# Epoch 12/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4802 - mse: 12.2263 - val_loss: 2.5327 - val_mse: 11.8171
# Epoch 13/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4854 - mse: 12.6647 - val_loss: 2.4988 - val_mse: 11.5399
# Epoch 14/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4717 - mse: 12.3339 - val_loss: 2.5022 - val_mse: 11.5506
# Epoch 15/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4731 - mse: 12.5157 - val_loss: 2.4754 - val_mse: 11.3196
# Epoch 16/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4734 - mse: 12.4380 - val_loss: 2.5187 - val_mse: 11.7238
# Epoch 17/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4858 - mse: 12.4717 - val_loss: 2.4590 - val_mse: 10.8576
# Epoch 18/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4672 - mse: 12.3092 - val_loss: 2.4936 - val_mse: 11.5454
# Epoch 19/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4729 - mse: 12.5392 - val_loss: 2.4703 - val_mse: 11.3900
# Epoch 20/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4691 - mse: 12.3818 - val_loss: 2.4912 - val_mse: 11.4316
# Epoch 21/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4633 - mse: 12.4735 - val_loss: 2.4912 - val_mse: 11.4146
# Epoch 22/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4718 - mse: 12.5248 - val_loss: 2.4638 - val_mse: 10.8748
# Epoch 23/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4880 - mse: 12.1699 - val_loss: 2.4609 - val_mse: 10.8917
# Epoch 24/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.5115 - mse: 12.8046 - val_loss: 2.4685 - val_mse: 10.9459
# Epoch 25/100
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4867 - mse: 12.5558 - val_loss: 2.4855 - val_mse: 11.3141
# Epoch 26/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4712 - mse: 12.1684 - val_loss: 2.4418 - val_mse: 10.5986
# Epoch 27/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4784 - mse: 12.2618 - val_loss: 2.4879 - val_mse: 11.3484
# Epoch 28/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4784 - mse: 12.5945 - val_loss: 2.4586 - val_mse: 10.7023
# Epoch 29/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.5238 - mse: 12.3269 - val_loss: 2.4528 - val_mse: 10.8114
# Epoch 30/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4795 - mse: 12.4179 - val_loss: 2.5345 - val_mse: 12.0002
# Epoch 31/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4673 - mse: 12.3517 - val_loss: 2.4484 - val_mse: 10.9416
# Epoch 32/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4971 - mse: 12.2636 - val_loss: 2.5179 - val_mse: 11.8460
# Epoch 33/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4796 - mse: 12.6213 - val_loss: 2.4675 - val_mse: 11.2895
# Epoch 34/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4737 - mse: 12.5105 - val_loss: 2.4943 - val_mse: 11.4046
# Epoch 35/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4757 - mse: 12.2962 - val_loss: 2.4966 - val_mse: 11.4119
# Epoch 36/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4811 - mse: 12.6975 - val_loss: 2.4995 - val_mse: 11.6042
# Epoch 37/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4758 - mse: 12.3193 - val_loss: 2.4587 - val_mse: 11.0689
# Epoch 38/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4974 - mse: 12.6558 - val_loss: 2.5371 - val_mse: 11.7397
# Epoch 39/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4880 - mse: 12.2879 - val_loss: 2.4660 - val_mse: 10.9435
# Epoch 40/100
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4862 - mse: 12.7631 - val_loss: 2.5211 - val_mse: 11.9466
# Epoch 41/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4639 - mse: 12.4336 - val_loss: 2.4585 - val_mse: 10.7409
# Epoch 42/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5151 - mse: 12.2633 - val_loss: 2.4901 - val_mse: 11.2237
# Epoch 43/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4710 - mse: 12.3530 - val_loss: 2.4506 - val_mse: 10.8489
# Epoch 44/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4675 - mse: 12.2812 - val_loss: 2.4873 - val_mse: 11.3897
# Epoch 45/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4803 - mse: 12.3964 - val_loss: 2.4727 - val_mse: 11.1943
# Epoch 46/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4778 - mse: 12.4217 - val_loss: 2.4724 - val_mse: 11.1398
# Epoch 47/100
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4928 - mse: 12.3251 - val_loss: 2.4845 - val_mse: 11.0740
# Epoch 48/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4776 - mse: 12.6634 - val_loss: 2.4933 - val_mse: 11.4452
# Epoch 49/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4931 - mse: 12.6516 - val_loss: 2.4744 - val_mse: 11.4141
# Epoch 50/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4763 - mse: 12.6068 - val_loss: 2.4676 - val_mse: 11.0703
# Epoch 51/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5037 - mse: 12.2891 - val_loss: 2.4562 - val_mse: 10.5428
# Epoch 52/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4712 - mse: 12.2307 - val_loss: 2.5069 - val_mse: 11.3092
# Epoch 53/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5295 - mse: 12.6642 - val_loss: 2.4590 - val_mse: 10.5230
# Epoch 54/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4751 - mse: 12.6082 - val_loss: 2.5088 - val_mse: 11.6812
# Epoch 55/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4807 - mse: 12.4864 - val_loss: 2.4917 - val_mse: 11.2351
# Epoch 56/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4715 - mse: 12.1229 - val_loss: 2.4900 - val_mse: 11.3082
# Epoch 57/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4731 - mse: 12.5321 - val_loss: 2.4994 - val_mse: 11.5941
# Epoch 58/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4719 - mse: 12.5158 - val_loss: 2.4958 - val_mse: 11.5905
# Epoch 59/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4937 - mse: 12.4590 - val_loss: 2.4852 - val_mse: 11.3905
# Epoch 60/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4830 - mse: 12.7228 - val_loss: 2.5101 - val_mse: 11.7150
# Epoch 61/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4952 - mse: 12.4460 - val_loss: 2.4977 - val_mse: 11.3628
# Epoch 62/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4670 - mse: 12.3933 - val_loss: 2.4834 - val_mse: 11.2935
# Epoch 63/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5023 - mse: 12.6801 - val_loss: 2.4538 - val_mse: 10.9413
# Epoch 64/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4742 - mse: 12.3211 - val_loss: 2.4731 - val_mse: 11.1907
# Epoch 65/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4831 - mse: 12.4323 - val_loss: 2.4454 - val_mse: 10.8063
# Epoch 66/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.5096 - mse: 12.0377 - val_loss: 2.4535 - val_mse: 10.8787
# Epoch 67/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5149 - mse: 12.7883 - val_loss: 2.4951 - val_mse: 11.6120
# Epoch 68/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5188 - mse: 12.4085 - val_loss: 2.4611 - val_mse: 10.8209
# Epoch 69/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4783 - mse: 12.2511 - val_loss: 2.5196 - val_mse: 11.6752
# Epoch 70/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4786 - mse: 12.4604 - val_loss: 2.4650 - val_mse: 11.0206
# Epoch 71/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4918 - mse: 12.1800 - val_loss: 2.4709 - val_mse: 10.8818
# Epoch 72/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4976 - mse: 12.6124 - val_loss: 2.4813 - val_mse: 10.9537
# Epoch 73/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.5019 - mse: 12.1323 - val_loss: 2.4808 - val_mse: 10.6746
# Epoch 74/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5319 - mse: 12.9585 - val_loss: 2.5006 - val_mse: 11.6235
# Epoch 75/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5040 - mse: 12.3541 - val_loss: 2.4705 - val_mse: 11.3580
# Epoch 76/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.5018 - mse: 12.7926 - val_loss: 2.5265 - val_mse: 11.9492
# Epoch 77/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4763 - mse: 12.5655 - val_loss: 2.4841 - val_mse: 11.4094
# Epoch 78/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4807 - mse: 12.2051 - val_loss: 2.4871 - val_mse: 11.1234
# Epoch 79/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4700 - mse: 12.4024 - val_loss: 2.4735 - val_mse: 11.0375
# Epoch 80/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4695 - mse: 12.2934 - val_loss: 2.4732 - val_mse: 11.1352
# Epoch 81/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4801 - mse: 12.4542 - val_loss: 2.4570 - val_mse: 10.9159
# Epoch 82/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4722 - mse: 12.4298 - val_loss: 2.4786 - val_mse: 11.0565
# Epoch 83/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.5045 - mse: 12.3699 - val_loss: 2.4647 - val_mse: 10.7871
# Epoch 84/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.5078 - mse: 12.8479 - val_loss: 2.4674 - val_mse: 11.1735
# Epoch 85/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4770 - mse: 12.3588 - val_loss: 2.4762 - val_mse: 11.2042
# Epoch 86/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4742 - mse: 12.3928 - val_loss: 2.4782 - val_mse: 11.1895
# Epoch 87/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2.4744 - mse: 12.3527 - val_loss: 2.4662 - val_mse: 11.0582
# Epoch 88/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4652 - mse: 12.2307 - val_loss: 2.4677 - val_mse: 10.9487
# Epoch 89/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4727 - mse: 12.4584 - val_loss: 2.4552 - val_mse: 10.7352
# Epoch 90/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4906 - mse: 12.3075 - val_loss: 2.4818 - val_mse: 11.1096
# Epoch 91/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2.4909 - mse: 12.6517 - val_loss: 2.4701 - val_mse: 10.9350
# Epoch 92/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.5104 - mse: 12.4136 - val_loss: 2.5208 - val_mse: 11.7558
# Epoch 93/100
# 8/8 [==============================] - 0s 9ms/step - loss: 2.4687 - mse: 12.5603 - val_loss: 2.4985 - val_mse: 11.4571
# Epoch 94/100
# 8/8 [==============================] - 0s 12ms/step - loss: 2.4936 - mse: 12.5069 - val_loss: 2.4773 - val_mse: 11.1777
# Epoch 95/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4695 - mse: 12.3405 - val_loss: 2.4899 - val_mse: 11.2453
# Epoch 96/100
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4854 - mse: 12.5110 - val_loss: 2.4973 - val_mse: 11.3975
# Epoch 97/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.5098 - mse: 12.1909 - val_loss: 2.4642 - val_mse: 11.1182
# Epoch 98/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4733 - mse: 12.4678 - val_loss: 2.5353 - val_mse: 12.1290
# Epoch 99/100
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4956 - mse: 12.6454 - val_loss: 2.4613 - val_mse: 11.2981
# Epoch 100/100
# 8/8 [==============================] - 0s 10ms/step - loss: 2.5058 - mse: 12.6973 - val_loss: 2.4783 - val_mse: 11.2559
# CPU times: total: 6.97 s
# Wall time: 6.34 s

# %% [markdown]
# Using all the inputs achieves a much lower training and validation error than the `horsepower` model:

# %%
plot_loss(history)

# %% [markdown]
# We'll collect the test set result in our previously defined dictionary for later:

# %%
test_results["linear_model"] = linear_model.evaluate(
    np.array(X_test).astype("float32"), y_test, verbose=0
)

# %% [markdown]
# ## A DNN regression

# %% [markdown]
# The previous section implemented linear models for single and multiple inputs.
#
# This section implements single-input and multiple-input DNN models. The code is basically the same except the model is expanded to include some "hidden"  non-linear layers. The name "hidden" here just means not directly connected to the inputs or outputs.

# %% [markdown]
# These models will contain a few more layers than the linear model:
#
# 1. The normalization layer.
# 2. Two hidden, nonlinear, `Dense` layers using the `gelu` nonlinearity.
# 3. A linear single-output layer.
#
# Both will use the same training procedure so we'll include the `compile` method in the newly defined `build_and_compile_model` function below.

# %%
def build_and_compile_model(norm):
    model = keras.Sequential(
        [
            norm,
            layers.Dense(64, activation="gelu"),
            layers.Dense(64, activation="gelu"),
            layers.Dense(1),
        ]
    )

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss=["mae"],
        metrics=["mse"],
    )
    return model

# %% [markdown]
# ### One variable

# %% [markdown]
# Let's start again with a DNN model for a single input: "Horsepower".
#
# We can use the normalization layer we've created for our first model.

# %%
dnn_horsepower_model = build_and_compile_model(horsepower_normalizer)

# %% [markdown]
# This model has quite a few more trainable parameters than the linear models.

# %%
dnn_horsepower_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normaliza  (None, 1)                 3
#  tion)
#
#  dense_2 (Dense)             (None, 64)                128
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4356 (17.02 KB)
# Trainable params: 4353 (17.00 KB)
# Non-trainable params: 3 (16.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Let's train the model:

# %%
# %%time
history = dnn_horsepower_model.fit(
    X_train["Horsepower"],
    y_train,
    validation_split=0.2,
    verbose=0,
    epochs=100,
    callbacks=get_callbacks("dnn_horsepower"),
)
# Out:
# CPU times: total: 12.2 s
# Wall time: 11.3 s

# %% [markdown]
# This model does slightly better than the linear-horsepower model.

# %%
plot_loss(history)

# %% [markdown]
# If you plot the predictions as a function of `Horsepower`, you'll see how this model takes advantage of the nonlinearity provided by the hidden layers:

# %%
x = tf.linspace(0.0, 250, 251)
y = dnn_horsepower_model.predict(x)
# Out:
# 8/8 [==============================] - 0s 0s/step

# %%
plot_horsepower(x, y)

# %% [markdown]
# We'll also collect the results on the test set, for later:

# %%
test_results["dnn_horsepower_model"] = dnn_horsepower_model.evaluate(
    X_train["Horsepower"], y_train, verbose=0
)

# %% [markdown]
# ### Full model

# %% [markdown]
# If you repeat this process using all the inputs it slightly improves the performance on the validation dataset.

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 9)                 19
#  on)
#
#  dense_5 (Dense)             (None, 64)                640
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4884 (19.08 KB)
# Trainable params: 4865 (19.00 KB)
# Non-trainable params: 19 (80.00 Byte)
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    X_train * 1.0,
    y_train,
    validation_split=0.2,
    verbose=0,
    epochs=100,
    callbacks=get_callbacks("dnn_model"),
)
# Out:
# CPU times: total: 15 s
# Wall time: 14.1 s

# %%
plot_loss(history)

# %% [markdown]
# Collect the results on the test set:

# %%
test_results["dnn_model"] = dnn_model.evaluate(X_test, y_test, verbose=0)

# %% [markdown]
# ## Performance

# %% [markdown]
# Now that all the models are trained let's check the test-set performance and compare how they performed:

# %%
pd.DataFrame(
    test_results, index=["Mean absolute error [MPG]", "Mean squared error [MPG]"]
).T
# Out:
#                       Mean absolute error [MPG]  Mean squared error [MPG]
# sklearn_model                          2.390000                 10.170000
# horsepower_model                       3.640891                 21.562542
# linear_model                           2.508310                 12.621125
# dnn_horsepower_model                   3.329854                 20.470173
# dnn_model                              1.727901                  5.871124

# %% [markdown]
# These results match the validation error seen during training.

# %% [markdown]
# ### Make predictions
#
# Finally, predict have a look at the errors made by the model when making predictions on the test set:

# %%
y_pred = dnn_model.predict(X_test).flatten()

a = plt.axes(aspect="equal")
plt.scatter(y_test, y_pred)
plt.xlabel("True Values [MPG]")
plt.ylabel("Predictions [MPG]")
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %% [markdown]
# It looks like the model predicts reasonably well.
#
# Now take a look at the error distribution:

# %%
error = y_pred - y_test
plt.hist(error, bins=25)
plt.xlabel("Prediction Error [MPG]")
_ = plt.ylabel("Count")

# %% [markdown]
# If you're happy with the model you can save it for later use:

# %%
dnn_model.save("dnn_model")
# Out:
# INFO:tensorflow:Assets written to: dnn_model\assets
# INFO:tensorflow:Assets written to: dnn_model\assets

# %% [markdown]
# If you reload the model, it will give you identical outputs:

# %%
reloaded = tf.keras.models.load_model("dnn_model")

test_results["reloaded"] = reloaded.evaluate(X_test, y_test, verbose=0)
# Out:
# WARNING:tensorflow:From c:\Users\thngu\neuefische_course\pepperprompt\fork-ds-artificial-neural-networks\.venv\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# WARNING:tensorflow:From c:\Users\thngu\neuefische_course\pepperprompt\fork-ds-artificial-neural-networks\.venv\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.

# %%
pd.DataFrame(
    test_results, index=["Mean absolute error [MPG]", "Mean squared error [MPG]"]
).T
# Out:
#                       Mean absolute error [MPG]  Mean squared error [MPG]
# sklearn_model                          2.390000                 10.170000
# horsepower_model                       3.640891                 21.562542
# linear_model                           2.508310                 12.621125
# dnn_horsepower_model                   3.329854                 20.470173
# dnn_model                              1.727901                  5.871124
# reloaded                               1.727901                  5.871124

# %% [markdown]
# ## Conclusion
#
# This notebook introduced a few techniques to handle a regression problem. Here are a few more tips that may help:
#
# * [Mean Squared Error (MSE)](https://www.tensorflow.org/api_docs/python/tf/losses/MeanSquaredError) and [Mean Absolute Error (MAE)](https://www.tensorflow.org/api_docs/python/tf/losses/MeanAbsoluteError) are common loss functions used for regression problems. Mean Absolute Error is less sensitive to outliers. Different loss functions are used for classification problems.
# * Similarly, evaluation metrics used for regression differ from classification.
# * When numeric input data features have values with different ranges, each feature should be scaled independently to the same range.
# * Overfitting is a common problem for DNN models, it wasn't a problem for this tutorial. See the [overfit and underfit](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit) tutorial for more help with this.

# %% [markdown]
# ---
# ## TensorBoard

# %% [markdown]
# In machine learning, to improve something you often need to be able to measure it. TensorBoard is a tool for providing the measurements and visualizations needed during the machine learning workflow. It enables tracking experiment metrics like loss and accuracy, visualizing the model graph, projecting embeddings to a lower dimensional space, and much more.
#
# TensorBoard can be used directly within a notebook in Colab and Jupyter. This can be helpful for sharing results, integrating TensorBoard into existing workflows, and using TensorBoard without installing anything locally.
#
# You can find a nice introductory notebook [here](https://www.tensorflow.org/tensorboard/get_started).
#
# When you are running this NB in a browster and the tensorboard cannot be displayed: If you are using Safari, try to switch to Google Chrome and run it again.

# %% [markdown]
# ### Example using TensorBoard

# %% [markdown]
# When training with Keras's `.fit()`, adding the `tf.keras.callbacks.TensorBoard` callback ensures that logs are created and stored. Additionally, enable histogram computation every epoch with histogram_freq=1 (this is turned off by default).
#
# We've saved the logs in a timestamped subdirectory to allow easy selection of different training runs.

# %%
# Load the TensorBoard notebook extension
# %reload_ext tensorboard

# %% [markdown]
# You can start TensorBoard within the notebook using magics. At the end of the command you need to specify the path where the log files are saved.

# %%
# %tensorboard --logdir=./my_logs
# Out:
#       <iframe id="tensorboard-frame-791003e91a941a02" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-791003e91a941a02");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# The tensorboard will be available at http://localhost:6006/
